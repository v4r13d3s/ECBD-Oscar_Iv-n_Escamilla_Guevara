# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from seaborn) (3.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from seaborn) (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
dfSucio = pd.read_csv("dataset_sucio_practica.csv")

# %%
#Mostrar las primeras filas
dfSucio.head(5)
# Out:
#    id          nombre   edad                 correo       pais  salario  \
# 0   1     Julia Zhang  150.0       aortiz@perry.com        NaN  25000.0
# 1   2             NaN   35.0     asimmons@garza.com     España      NaN
# 2   3    George Burke   40.0  mcclainerin@gmail.com  Argentina      NaN
# 3   4  Joyce Williams   30.0        correo_invalido  Argentina  25000.0
# 4   5  Elaine Sanchez   -5.0        correo_invalido     México  25000.0
#
#   fecha_registro activo
# 0     2026-03-09     Sí
# 1     2026-05-04     No
# 2     2026-01-27    NaN
# 3     2025-02-23     No
# 4     2025-03-28     Sí

# %%
dfSucio.shape
# Out:
# (125, 8)

# %%
dfSucio.tail()
# Out:
#      id          nombre   edad                 correo       pais  salario  \
# 120   1     Julia Zhang  150.0       aortiz@perry.com        NaN  25000.0
# 121   2             NaN   35.0     asimmons@garza.com     España      NaN
# 122   3    George Burke   40.0  mcclainerin@gmail.com  Argentina      NaN
# 123   4  Joyce Williams   30.0        correo_invalido  Argentina  25000.0
# 124   5  Elaine Sanchez   -5.0        correo_invalido     México  25000.0
#
#     fecha_registro activo
# 120     2026-03-09     Sí
# 121     2026-05-04     No
# 122     2026-01-27    NaN
# 123     2025-02-23     No
# 124     2025-03-28     Sí

# %%
dfSucio.describe()
# Out:
#                id        edad       salario       fecha_registro      activo
# count  120.000000  120.000000    120.000000                  120  120.000000
# mean    60.500000   30.325000  16741.666667  2025-06-07 04:12:00    0.675000
# min      1.000000   22.000000  12000.000000  2024-05-31 00:00:00    0.000000
# 25%     30.750000   30.000000  15000.000000  2024-11-15 00:00:00    0.000000
# 50%     60.500000   30.000000  15000.000000  2025-06-19 12:00:00    1.000000
# 75%     90.250000   31.250000  18000.000000  2025-12-18 18:00:00    1.000000
# max    120.000000   40.000000  25000.000000  2026-05-04 00:00:00    1.000000
# std     34.785054    4.745918   4401.099621                  NaN    0.470339

# %%
dfSucio[dfSucio["id"].isin([29, 55, 58])]
# Out:
#     id           nombre  edad                    correo    pais  salario  \
# 28  29     Teresa Ramos  22.0  rileyraymond@hotmail.com  México  -1000.0
# 54  55       John Lewis   NaN  rodriguezbrett@yahoo.com  México  -1000.0
# 57  58  Michael Barajas  40.0    antoniocox@hotmail.com  España  15000.0
#
#    fecha_registro activo
# 28     2025-08-29    NaN
# 54     2024-07-03    NaN
# 57     2026-05-02    NaN

# %%
#Generamos una copia por cualquier cosa
dfCopy = dfSucio.copy()

# %%
dfSucio.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              125 non-null    int64
#  1   nombre          116 non-null    str
#  2   edad            110 non-null    float64
#  3   correo          125 non-null    str
#  4   pais            82 non-null     str
#  5   salario         107 non-null    float64
#  6   fecha_registro  125 non-null    str
#  7   activo          90 non-null     str
# dtypes: float64(2), int64(1), str(5)
# memory usage: 7.9 KB

# %%
plt.figure(figsize = (12, 6))
sns.heatmap(dfSucio.isnull(), cbar = False)
plt.title("Mapa de valores nulos")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
dfSucio.duplicated().sum()
# Out:
# np.int64(5)

# %%
dfSucio.drop_duplicates(inplace=True)

# %%
#Corregir edades invalidas
dfSucio[(dfSucio["edad"] < 0) | (dfSucio["edad"] > 100)]
# Out:
# Empty DataFrame
# Columns: [id, nombre, edad, correo, pais, salario, fecha_registro, activo]
# Index: []

# %%
dfSucio.loc[(dfSucio["edad"] < 0) | (dfSucio["edad"] > 110), "edad"] = np.nan

# %%
#Calculamos la mediana de la edad
mediana_edad = dfSucio["edad"].median()

# %%
mediana_edad
# Out:
# np.float64(30.0)

# %%
dfSucio["edad"] = dfSucio["edad"].fillna (mediana_edad)

# %%
dfSucio["edad"].describe()
# Out:
# count    120.000000
# mean      30.325000
# std        4.745918
# min       22.000000
# 25%       30.000000
# 50%       30.000000
# 75%       31.250000
# max       40.000000
# Name: edad, dtype: float64

# %%
#Corregimos anomalia de salarios negativos
dfSucio[dfSucio["salario"] < 0]
# Out:
# Empty DataFrame
# Columns: [id, nombre, edad, correo, pais, salario, fecha_registro, activo]
# Index: []

# %%
dfSucio.loc[(dfSucio["salario"] < 0), "salario"] = np.nan

# %%
mediana_salario = dfSucio["salario"].median()

# %%
mediana_salario
# Out:
# np.float64(15000.0)

# %%
dfSucio["salario"] = dfSucio["salario"] .fillna(mediana_salario)

# %%
dfSucio["salario"].describe()
# Out:
# count      120.000000
# mean     16741.666667
# std       4401.099621
# min      12000.000000
# 25%      15000.000000
# 50%      15000.000000
# 75%      18000.000000
# max      25000.000000
# Name: salario, dtype: float64

# %%
#Corregir correos no validos
dfSucio[~dfSucio["correo"] .str.contains("@", na = False)]
# Out:
#     id             nombre  edad correo       pais  salario fecha_registro  \
# 3    4     Joyce Williams  30.0    NaN  Argentina  25000.0     2025-02-23
# 4    5     Elaine Sanchez  30.0    NaN     México  25000.0     2025-03-28
# 18  19     Nicholas Curry  35.0    NaN     México  12000.0     2025-11-22
# 21  22    Carrie Griffith  30.0    NaN  Argentina  15000.0     2025-05-05
# 30  31  Mrs. Sara Johnson  35.0    NaN  Argentina  15000.0     2026-03-07
# 40  41     Cynthia Arnold  30.0    NaN  Argentina  25000.0     2024-11-03
# 65  66      Michael Lopez  40.0    NaN     España  15000.0     2025-12-01
# 78  79       Charles Page  25.0    NaN  Argentina  15000.0     2025-09-01
# 87  88                NaN  22.0    NaN  Argentina  12000.0     2025-03-07
# 88  89      Erika Bernard  30.0    NaN  Argentina  12000.0     2024-11-16
# 94  95        Daniel Wong  30.0    NaN     España  15000.0     2026-04-29
# 95  96         Luis Drake  25.0    NaN  Argentina  25000.0     2025-01-22
#
#     activo
# 3        0
# 4        1
# 18       1
# 21       1
# 30       1
# 40       0
# 65       0
# 78       0
# 87       1
# 88       1
# 94       0
# 95       1

# %%
#Correos no validos
correo_invalido = ~dfSucio["correo"] .str.contains("@", na = False)
dfSucio.loc [correo_invalido, "correo"] = pd.NA

# %%
#Corregir países no asignados
dfSucio["pais"].isnull().sum()
# Out:
# np.int64(0)

# %%
moda_pais = dfSucio["pais"].mode()[0]

# %%
moda_pais
# Out:
# 'Argentina'

# %%
dfSucio["pais"] = dfSucio["pais"].fillna(moda_pais)

# %%
dfSucio.dtypes
# Out:
# id                         int64
# nombre                       str
# edad                     float64
# correo                       str
# pais                         str
# salario                  float64
# fecha_registro    datetime64[us]
# activo                       str
# dtype: object

# %%
#Convertimos la fecha
dfSucio["fecha_registro"] = pd.to_datetime(dfSucio["fecha_registro"])

# %%
dfSucio["fecha_registro"] .dt.year
# Out:
# 0      2026
# 1      2026
# 2      2026
# 3      2025
# 4      2025
#        ...
# 115    2024
# 116    2024
# 117    2026
# 118    2025
# 119    2026
# Name: fecha_registro, Length: 120, dtype: int32

# %%
#Categorizar el campo activo
dfSucio["activo"] .value_counts(dropna = False)
# Out:
# activo
# Sí    81
# No    39
# Name: count, dtype: int64

# %%
dfSucio ["activo"] = dfSucio ["activo"].fillna ("Sí")

# %%
#Convertimos a binario
dfSucio ["activo"] = dfSucio ["activo"] .map({
    "Sí": 1,
    "No": 0
})

# %%
dfSucio["activo"] .value_counts(dropna = False)
# Out:
# activo
# 1    81
# 0    39
# Name: count, dtype: int64

# %%
(dfSucio.isnull().sum()/len (dfSucio)) * 100
# Out:
# id                 0.000000
# nombre             6.666667
# edad               0.000000
# correo            10.000000
# pais               0.000000
# salario            0.000000
# fecha_registro     0.000000
# activo             0.000000
# dtype: float64

# %%
# Conclusiones
Durante la práctica se identificaron y corrigieron los siguientes problemas:
1. Borrar los datos duplicados
2. Corregir datos invalidos y atipicos
3. Realizar y corregir tipos de datos
4. Categorizar campos que sean necesarios
