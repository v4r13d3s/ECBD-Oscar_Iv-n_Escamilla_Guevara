# %%
import pandas as pd

# %%
datos = {
    "usuario" : ["Ana", "Luis", "Martha", "Carolina", "Sofía", "Pedro", "Elena", "Diego"],
    "Edad" : [25, 32, 28, 45, 37, 22, 31, 32],
    "ciudad" : ["CDMX", "Monterrey", "Guadalajara", "Puebla", "Cancún", "Merida", "Tijuana", "Toluca"],
    "compras_realizadas" : [5, 12, 21, 14, 34, 29, 31, 15],
    "activo" : [True, False, True, False, True, False, True, False],
    "fecha_registro" : ["2025-05-14", "2025-12-25", "2025-02-15", "2025-11-24", "2025-01-21", "2025-09-24", "2025-08-22", "2025-08-06"],
}

# %%
#Convertir a dataframe
df = pd.DataFrame(datos)

# %%
print(df)
# Out:
#     usuario  Edad       ciudad  compras_realizadas  activo fecha_registro
# 0       Ana    25         CDMX                   5    True     2025-05-14
# 1      Luis    32    Monterrey                  12   False     2025-12-25
# 2    Martha    28  Guadalajara                  21    True     2025-02-15
# 3  Carolina    45       Puebla                  14   False     2025-11-24
# 4     Sofía    37       Cancún                  34    True     2025-01-21
# 5     Pedro    22       Merida                  29   False     2025-09-24
# 6     Elena    31      Tijuana                  31    True     2025-08-22
# 7     Diego    32       Toluca                  15   False     2025-08-06

# %%
#Especificar los primeros 5 valores
df.head()
# Out:
#     usuario  Edad       ciudad  compras_realizadas  activo fecha_registro
# 0       Ana    25         CDMX                   5    True     2025-05-14
# 1      Luis    32    Monterrey                  12   False     2025-12-25
# 2    Martha    28  Guadalajara                  21    True     2025-02-15
# 3  Carolina    45       Puebla                  14   False     2025-11-24
# 4     Sofía    37       Cancún                  34    True     2025-01-21

# %%
cantidad = 1000000

# %%
import random

# %%
#Datos aleatorios
nombres = ["Ana", "Luis", "Martha", "Carolina", "Sofía", "Pedro", "Elena", "Diego"]
ciudades = ["CDMX", "Monterrey", "Guadalajara", "Puebla", "Cancún", "Merida", "Tijuana", "Toluca"]
categorias = ["Tecnologías", "Ropa", "Hogar", "Videojuegos", "Deportes", "Calzado", "Cosmeticos", "Infantil"]

# %%
#Creación del dataframe
dMilton = pd.DataFrame ({
    "nombre" : [random.choice(nombres) for _ in range(cantidad)],
    "ciudad" : [random.choice(ciudades) for _ in range(cantidad)],
    "categoria" : [random.choice(categorias) for _ in range(cantidad)],
    "edad" : [random.randint(18,70) for _ in range(cantidad)],
    "salario" : [round(random.uniform(5000, 50000), 2) for _ in range (cantidad)],
    "activo" : [random.choice([True,False]) for _ in range(cantidad)],
    "anio_registro" : [random.randint(2020,2026) for _ in range(cantidad)],

})

# %%
dMilton.dtypes
# Out:
# nombre               str
# ciudad               str
# categoria            str
# edad               int64
# salario          float64
# activo              bool
# anio_registro      int64
# dtype: object

# %%
dMilton.memory_usage(deep=True)
# Out:
# Index                 132
# nombre           65124111
# ciudad           66859210
# categoria        68008055
# edad              8000000
# salario           8000000
# activo            1000000
# anio_registro     8000000
# dtype: int64

# %%
dMilton.memory_usage(deep=True).sum() /1024**2
# Out:
# np.float64(214.56862258911133)
