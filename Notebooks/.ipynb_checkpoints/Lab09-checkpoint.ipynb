# %%
¿Porqué una empresa podría no compartir sus datos reales?
¿Que sesgos existen al utilizar la información personal de los clientes?

# %%
pip install Faker
# Out:
# Requirement already satisfied: Faker in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (40.21.0)
# Requirement already satisfied: tzdata in C:\Users\Oscar\anaconda3\envs\Extraccion9BEscolarizado\Lib\site-packages (from Faker) (2026.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importar librerias
from faker import Faker

# %%
import pandas as pd

# %%
import random

# %%
fake = Faker("es_MX")

# %%
# Generamos datos sintéticos: 100 registros
datos = []
for i in range(100):   
    datos.append({    
        "id_usuario": i + 1,  
        "nombre": fake.name(),
        "correo": fake.email(),
        "edad": random.randint(18, 67),
        "seguidores": random.randint(100, 5000),
        "plataforma": random.choice(
            ["Tiktok", "Instagram", "Youtube"]
        )
    })

# %%
df = pd.DataFrame(datos)
df.head()
# Out:
#    id_usuario                         nombre                        correo  \
# 0           1          Srita. Silvia Centeno  franciscaherrera@example.org
# 1           2      Bernabé Cristian Meléndez       ericsegovia@example.net
# 2           3     Elias Jos Martínez Cuellar          tjiminez@example.com
# 3           4              Lic. Reina Montez     maria-elena69@example.com
# 4           5  Lucas Emilio Candelaria Lemus      jorge-luis31@example.com
#
#    edad  seguidores plataforma
# 0    39        1124    Youtube
# 1    35        3356    Youtube
# 2    32        1699    Youtube
# 3    40         327    Youtube
# 4    37        2435     Tiktok

# %%
#Estadistica descriptiva
df.describe(include="all")
# Out:
#         id_usuario                 nombre                        correo  \
# count   100.000000                    100                           100
# unique         NaN                    100                           100
# top            NaN  Srita. Silvia Centeno  franciscaherrera@example.org
# freq           NaN                      1                             1
# mean     50.500000                    NaN                           NaN
# std      29.011492                    NaN                           NaN
# min       1.000000                    NaN                           NaN
# 25%      25.750000                    NaN                           NaN
# 50%      50.500000                    NaN                           NaN
# 75%      75.250000                    NaN                           NaN
# max     100.000000                    NaN                           NaN
#
#               edad   seguidores plataforma
# count   100.000000   100.000000        100
# unique         NaN          NaN          3
# top            NaN          NaN     Tiktok
# freq           NaN          NaN         38
# mean     44.460000  2290.100000        NaN
# std      13.704987  1347.994751        NaN
# min      18.000000   105.000000        NaN
# 25%      33.750000  1115.750000        NaN
# 50%      44.000000  2316.000000        NaN
# 75%      57.000000  3352.250000        NaN
# max      67.000000  4862.000000        NaN

# %%
# Importar librerías para graficar
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Distribución de edades
plt.figure(figsize=(8,4))
sns.histplot(
    df["edad"],
    bins=10
)
plt.title("Distribución de edades")
plt.show()

# %%
sns.countplot(
    x="plataforma",
    data=df
)
plt.show()

# %%
#Generamos una copia para contaminarla
df_sucio = df.copy()

# %%
#Le colocamos valores nulos
for i in random.sample(range(len(df_sucio)), 5):
    df_sucio.loc[i,"nombre"] = None

# %%
df_sucio.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_usuario  100 non-null    int64
#  1   nombre      95 non-null     str
#  2   correo      100 non-null    str
#  3   edad        100 non-null    int64
#  4   seguidores  100 non-null    int64
#  5   plataforma  100 non-null    str
# dtypes: int64(3), str(3)
# memory usage: 4.8 KB

# %%
# edades invalidas
for i in random.sample(range(len(df_sucio)),5):
    df_sucio.loc[i,"edad"] = -10

# %%
df_sucio.describe()["edad"]
# Out:
# count    100.000000
# mean      41.550000
# std       17.936687
# min      -10.000000
# 25%       32.000000
# 50%       42.500000
# 75%       56.000000
# max       67.000000
# Name: edad, dtype: float64

# %%
# seguidores imposibles
for i in random.sample(range(len(df_sucio)),5):
    df_sucio.loc[i,"seguidores"] = 500000

# %%
df_sucio.describe()["seguidores"]
# Out:
# count       100.00000
# mean      27182.06000
# std      109026.26177
# min         105.00000
# 25%        1124.75000
# 50%        2402.50000
# 75%        3512.00000
# max      500000.00000
# Name: seguidores, dtype: float64

# %%
#Generamos correos invalidos
for i in random.sample(range(len(df_sucio)),5):
    df_sucio.loc[i,"correo"] = "correo_invalido"

# %%
df_sucio.describe(include=["str", "object"])
# Out:
#                        nombre           correo plataforma
# count                      95              100        100
# unique                     95               96          3
# top     Srita. Silvia Centeno  correo_invalido     Tiktok
# freq                        1                5         38

# %%
df_sucio.isnull().sum()
# Out:
# id_usuario    0
# nombre        5
# correo        0
# edad          0
# seguidores    0
# plataforma    0
# dtype: int64

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
#Estadisticas
df_sucio.describe(include="all")
# Out:
#         id_usuario                 nombre           correo   edad  seguidores  \
# count       100.00                     95              100 100.00      100.00
# unique         NaN                     95               96    NaN         NaN
# top            NaN  Srita. Silvia Centeno  correo_invalido    NaN         NaN
# freq           NaN                      1                5    NaN         NaN
# mean         50.50                    NaN              NaN  41.55    27182.06
# std          29.01                    NaN              NaN  17.94   109026.26
# min           1.00                    NaN              NaN -10.00      105.00
# 25%          25.75                    NaN              NaN  32.00     1124.75
# 50%          50.50                    NaN              NaN  42.50     2402.50
# 75%          75.25                    NaN              NaN  56.00     3512.00
# max         100.00                    NaN              NaN  67.00   500000.00
#
#        plataforma
# count         100
# unique          3
# top        Tiktok
# freq           38
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN
