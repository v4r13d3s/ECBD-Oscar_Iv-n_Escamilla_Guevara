# %%
# Importar librerias

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_wine

import seaborn as sns
import matplotlib.pyplot as plt

# %%
wine = load_wine(as_frame = True)

# %%
print(wine.DESCR)
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 178
# :Number of Attributes: 13 numeric, predictive attributes and the class
# :Attribute Information:
#     - Alcohol
#     - Malic acid
#     - Ash
#     - Alcalinity of ash
#     - Magnesium
#     - Total phenols
#     - Flavanoids
#     - Nonflavanoid phenols
#     - Proanthocyanins
#     - Color intensity
#     - Hue
#     - OD280/OD315 of diluted wines
#     - Proline
#     - class:
#         - class_0
#         - class_1
#         - class_2
#
# :Summary Statistics:
#
# ============================= ==== ===== ======= =====
#                                 Min   Max   Mean     SD
# ============================= ==== ===== ======= =====
# Alcohol:                      11.0  14.8    13.0   0.8
# Malic Acid:                   0.74  5.80    2.34  1.12
# Ash:                          1.36  3.23    2.36  0.27
# ...

# %%
dfWine = wine.frame

# %%
dfWine.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %% [markdown]
# ## Exploración del conjunto de datos

# %%
dfWine.shape
# Out:
# (178, 14)

# %%
dfWine.columns
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline', 'target'],
#       dtype='object')

# %%
wine.target_names
# Out:
# array(['class_0', 'class_1', 'class_2'], dtype='<U7')

# %% [markdown]
# ## Renombrar la columna target

# %%
dfWine.rename(columns = {"target": "especie"}, inplace = True)

# %%
dfWine["especie"] = dfWine["especie"].map({
    0: "class_0",
    1: "class_1",
    2: "class_2"
})

# %%
dfWine.head(100)
# Out:
#     alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0     14.23        1.71  2.43               15.6      127.0           2.80
# 1     13.20        1.78  2.14               11.2      100.0           2.65
# 2     13.16        2.36  2.67               18.6      101.0           2.80
# 3     14.37        1.95  2.50               16.8      113.0           3.85
# 4     13.24        2.59  2.87               21.0      118.0           2.80
# ..      ...         ...   ...                ...        ...            ...
# 95    12.47        1.52  2.20               19.0      162.0           2.50
# 96    11.81        2.12  2.74               21.5      134.0           1.60
# 97    12.29        1.41  1.98               16.0       85.0           2.55
# 98    12.37        1.07  2.10               18.5       88.0           3.52
# 99    12.29        3.17  2.21               18.0       88.0           2.85
#
# ...

# %%
dfWine.tail()
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 173        0.61                  0.52             1.06              7.7  0.64
# 174        0.75                  0.43             1.41              7.3  0.70
# 175        0.69                  0.43             1.35             10.2  0.59
# 176        0.68                  0.53             1.46              9.3  0.60
# 177        0.76                  0.56             1.35              9.2  0.61
#
# ...

# %% [markdown]
# ## Identificar variables predictoras y variables objetivo

# %%
# Variables predictoras

X = dfWine.drop(columns = ["especie"])

# %%
print("Variables predictoras")
print(X.columns)
# Out:
# Variables predictoras
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline'],
#       dtype='object')

# %%
# Variable objetivo

y = dfWine["especie"]

# %%
print("Variables predictoras")
print(y.name)
# Out:
# Variables predictoras
# especie

# %% [markdown]
# ## Evaluar los datos en prueba y entrenamiento
# Vamos a evaluar los datos 80% para entrenamiento y 20% para prueba

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify = y
)

# %%
print("X_train", X_train.shape)
print("X_test", X_test.shape)
print("y_train", y_train.shape)
print("y_test", y_test.shape)
# Out:
# X_train (142, 13)
# X_test (36, 13)
# y_train (142,)
# y_test (36,)

# %% [markdown]
# ## Escalado de variables

# %%
scaler = StandardScaler()

# %%
# Escalamos las variables

X_train_escalado = scaler.fit_transform(
    X_train
)
X_test_escalado = scaler.transform(
    X_test
)

# %%
print("Sin escalar")
print(X_train.head())
print("Escalado")
print(X_train_escalado[:5])
# Out:
# Sin escalar
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 36     13.28        1.64  2.84               15.5      110.0           2.60
# 30     13.73        1.50  2.70               22.5      101.0           3.00
# 26     13.39        1.77  2.62               16.1       93.0           2.85
# 12     13.75        1.73  2.41               16.0       89.0           2.60
# 148    13.32        3.24  2.38               21.5       92.0           1.93
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 36         2.68                  0.34             1.36             4.60  1.09
# 30         3.25                  0.29             2.38             5.70  1.19
# 26         2.94                  0.34             1.45             4.80  0.92
# 12         2.76                  0.29             1.81             5.60  1.15
# 148        0.76                  0.45             1.25             8.42  0.55
#
# ...

# %% [markdown]
# ## Entrenamiento del modelo KNN
# En esta prueba utilizaremos k = 3

# %%
modelo = KNeighborsClassifier(n_neighbors = 3)

# %%
modelo.fit(
    X_train_escalado, y_train
)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ## Realizando predicciones, con las variables de prueba

# %%
prediccion = modelo.predict(X_test_escalado)

# %%
print(prediccion[:10])
# Out:
# ['class_0' 'class_2' 'class_0' 'class_0' 'class_1' 'class_0' 'class_0'
#  'class_1' 'class_1' 'class_2']

# %%
## Comparación entre valores reales y valores predecidos
comparacion = pd.DataFrame({
    "especie real": y_test.values,
    "especie predicha": prediccion
})

# %%
comparacion.head(40)
# Out:
#    especie real especie predicha
# 0       class_0          class_0
# 1       class_2          class_2
# 2       class_0          class_0
# 3       class_1          class_0
# 4       class_1          class_1
# 5       class_0          class_0
# 6       class_0          class_0
# 7       class_1          class_1
# 8       class_1          class_1
# 9       class_2          class_2
# 10      class_1          class_1
# 11      class_2          class_2
# 12      class_0          class_0
# 13      class_2          class_2
# 14      class_0          class_0
# 15      class_1          class_1
# 16      class_1          class_1
# 17      class_0          class_0
# 18      class_1          class_1
# 19      class_0          class_0
# 20      class_1          class_1
# 21      class_1          class_1
# 22      class_0          class_0
# 23      class_0          class_0
# 24      class_1          class_1
# 25      class_1          class_1
# 26      class_0          class_0
# ...

# %% [markdown]
# ## Evaluación del modelo Accurancy
# Representa la cantdad de predicciones correctas que dio el modelo.

# %%
accuracy = accuracy_score(y_test, prediccion)
print(f"accuracy/exactitud:  {accuracy: .4f}")
# Out:
# accuracy/exactitud:   0.9722

# %%
from sklearn.metrics import confusion_matrix

# Matriz de confusión
cm = confusion_matrix(y_test, prediccion)

# %%
cm_df = pd.DataFrame(
    cm,
    index = modelo.classes_,
    columns = modelo.classes_
)
cm_df
# Out:
#          class_0  class_1  class_2
# class_0       12        0        0
# class_1        1       13        0
# class_2        0        0       10

# %% [markdown]
# ## Clasification report
# Proporciona metricas que permiten evaluar el desempeño de cada clase: Precision, recall, f1-score, support

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, prediccion ))
# Out:
#               precision    recall  f1-score   support
#
#      class_0       0.92      1.00      0.96        12
#      class_1       1.00      0.93      0.96        14
#      class_2       1.00      1.00      1.00        10
#
#     accuracy                           0.97        36
#    macro avg       0.97      0.98      0.97        36
# weighted avg       0.97      0.97      0.97        36
