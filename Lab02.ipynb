# %%
import pandas as pd

# %%
datos = pd.DataFrame({
    "Influencer": ["AnaFit", "CarlosTech", "SofiaTravel", "LuisGamer", "ValeFood", "MartaStyle", "DiegoMusic", "ElenaLife"],
    "likes": [1250, 8420, 5300, 12780, 4680, 3910, 9780, 6150],
    "comentarios": ["Muy bueno", "Genial", "Me gusta", "Buen video", "Qué rico", "Lindo", "Buen ritmo", "Excelente"],
    "fecha": ["2025-01-10", "2025-01-18", "2025-02-03", "2025-02-15", "2025-03-01", "2025-03-12", "2025-04-05", "2025-04-20"],
    "tipo_post": ["foto", "video", "reel", "stream", "carrusel", "story", "video","reel"]
})

# %%
df = pd.DataFrame(datos)

# %%
print(df)
# Out:
#     Influencer  likes comentarios       fecha tipo_post
# 0       AnaFit   1250   Muy bueno  2025-01-10      foto
# 1   CarlosTech   8420      Genial  2025-01-18     video
# 2  SofiaTravel   5300    Me gusta  2025-02-03      reel
# 3    LuisGamer  12780  Buen video  2025-02-15    stream
# 4     ValeFood   4680    Qué rico  2025-03-01  carrusel
# 5   MartaStyle   3910       Lindo  2025-03-12     story
# 6   DiegoMusic   9780  Buen ritmo  2025-04-05     video
# 7    ElenaLife   6150   Excelente  2025-04-20      reel

# %%
df.head()
# Out:
#     Influencer  likes comentarios       fecha tipo_post
# 0       AnaFit   1250   Muy bueno  2025-01-10      foto
# 1   CarlosTech   8420      Genial  2025-01-18     video
# 2  SofiaTravel   5300    Me gusta  2025-02-03      reel
# 3    LuisGamer  12780  Buen video  2025-02-15    stream
# 4     ValeFood   4680    Qué rico  2025-03-01  carrusel

# %%
cantidad = 1000000

# %%
import random

# %%
#Importamos datos aleatorios
temas = ["Gaming", "Moda", "Viajes", "Tecnología", "Fitness", "Comida", "Música", "Fotografía"]
categorias = ["Reel", "Story", "Video", "Post", "Directo", "Carrusel", "Short", "Tutorial"]
nombres = ["AnaFit", "CarlosTech", "SofiaTrips", "LuisPlay", "ValeFood", "MartaStyle", "DiegoMusic", "ElenaPics"]

# %%
#Creación del dataframe
dMillon = pd.DataFrame ({
    "nombre" : [random.choice(nombres) for _ in range(cantidad)],
    "recomendaciones" : [random.choice(temas) for _ in range(cantidad)],
    "categoria" : [random.choice(categorias) for _ in range(cantidad)],
    "edad" : [random.randint(18,70) for _ in range(cantidad)],
    "raiting" : [round(random.uniform(5000, 50000), 2) for _ in range (cantidad)],
    "activo" : [random.choice([True,False]) for _ in range(cantidad)],
    "fecha_registro" : [random.randint(2020,2026) for _ in range(cantidad)],

})

# %%
dMilton.dtypes
